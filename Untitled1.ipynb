# %% [markdown]
# # 데이터 전처리

# %%
import pandas as pd
import numpy as np
import seaborn as sns

def labelencoder(df): 
    encoders = {}
    i = 0
    for c in df.columns:
        encoders[i] = None
        if df[c].dtype=='object': 
            df[c] = df[c].fillna('N')
            lbl = LabelEncoder()
            lbl.fit(list(df[c].values))
            df[c] = lbl.transform(df[c].values)
            encoders[i] = lbl
        i += 1
    return df, encoders

df = pd.read_csv('./seoul_house_price.csv')

# df, encoder = labelencoder(df)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17785 entries, 0 to 17784
# Data columns (total 39 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                17785 non-null  object
#  1   Type                17785 non-null  object
#  2   Build               17785 non-null  int64
#  3   Dir                 17785 non-null  object
#  4   minArea             17785 non-null  float64
#  5   maxArea             17785 non-null  float64
#  6   representativeArea  17785 non-null  float64
#  7   floorAreaRatio      17785 non-null  int64
#  8   minDeal             16561 non-null  float64
#  9   maxDeal             16561 non-null  float64
#  10  medianDeal          16561 non-null  float64
#  11  minLease            12479 non-null  float64
#  12  maxLease            12479 non-null  float64
#  13  medianLease         10016 non-null  float64
#  14  minDealUnit         16561 non-null  float64
#  15  maxDealUnit         16561 non-null  float64
#  16  medianDealUnit      16561 non-null  float64
#  17  minLeaseUnit        12479 non-null  float64
#  18  maxLeaseUnit        12479 non-null  float64
#  19  medianLeaseUnit     10016 non-null  float64
#  20  Lat                 17785 non-null  float64
#  21  Lon                 17785 non-null  float64
#  22  BUS                 17785 non-null  int64
#  23  METRO               17785 non-null  int64
#  24  INFANT              17785 non-null  int64
#  25  PRESCHOOL           17785 non-null  int64
#  26  HOSPITAL            17785 non-null  int64
#  27  PARKING             17785 non-null  int64
#  28  MART                17785 non-null  int64
#  29  CONVENIENCE         17785 non-null  int64
#  30  WASHING             17785 non-null  int64
#  31  BANK                17785 non-null  int64
#  32  OFFICE              17785 non-null  int64
#  33  PRI_SCHOOL          17785 non-null  int64
#  34  PUB_SCHOOL          17785 non-null  int64
#  35  Old                 17785 non-null  object
#  36  sector              17785 non-null  object
#  37  divisition          17785 non-null  object
#  38  city                17785 non-null  object
# dtypes: float64(17), int64(15), object(7)
# memory usage: 5.3+ MB

# %% [markdown]
# ## Feature

# %%
features = ['Type', 'Dir' ,'Old', 'sector', 'divisition', 'representativeArea', 'floorAreaRatio', 'BUS', 'METRO', 'INFANT', 'PRESCHOOL', 'HOSPITAL', 'PARKING', 'MART', 'CONVENIENCE', 'BANK', 'OFFICE', 'PRI_SCHOOL', 'PUB_SCHOOL']
label = 'minLease'

headers = [label]
headers.extend(features)

pre_df = df[headers].copy()

pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17785 entries, 0 to 17784
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   minLease            12479 non-null  float64
#  1   Type                17785 non-null  object
#  2   Dir                 17785 non-null  object
#  3   Old                 17785 non-null  object
#  4   sector              17785 non-null  object
#  5   divisition          17785 non-null  object
#  6   representativeArea  17785 non-null  float64
#  7   floorAreaRatio      17785 non-null  int64
#  8   BUS                 17785 non-null  int64
#  9   METRO               17785 non-null  int64
#  10  INFANT              17785 non-null  int64
#  11  PRESCHOOL           17785 non-null  int64
#  12  HOSPITAL            17785 non-null  int64
#  13  PARKING             17785 non-null  int64
#  14  MART                17785 non-null  int64
#  15  CONVENIENCE         17785 non-null  int64
#  16  BANK                17785 non-null  int64
#  17  OFFICE              17785 non-null  int64
#  18  PRI_SCHOOL          17785 non-null  int64
#  19  PUB_SCHOOL          17785 non-null  int64
# dtypes: float64(2), int64(13), object(5)
# memory usage: 2.7+ MB

# %%
#floorAreaRatio - 0 : missing value

drops = ['representativeArea', 'floorAreaRatio', label]

for dr in drops:
    pre_df.loc[:,dr] = pre_df[dr].copy().apply(lambda x : None if x == 0 else x)
pre_df.dropna(inplace=True)
pre_df.reset_index(drop=True, inplace=True)
pre_df
# Out:
#        minLease  Type Dir     Old sector divisition  representativeArea  \
# 0       24000.0  OPST  EE     New    가락동        송파구                31.0
# 1       29000.0  OPST  EE     New    가락동        송파구                29.0
# 2       73000.0   APT  EE     Old    가락동        송파구               182.0
# 3       67000.0   APT  EE     New    가락동        송파구               110.0
# 4      125000.0   APT  EE     Old    가락동        송파구               141.0
# ...         ...   ...  ..     ...    ...        ...                 ...
# 11749  130000.0   APT  WS  Common    흥인동         중구               163.0
# 11750   15000.0   APT  SS  Common    흥인동         중구                25.0
# 11751   22200.0  OPST  SS  Common    흥인동         중구                37.0
# 11752  130000.0   APT  SS  Common    흥인동         중구               163.0
# 11753  130000.0   APT  EN  Common    흥인동         중구               163.0
#
#        floorAreaRatio  BUS  METRO  INFANT  PRESCHOOL  HOSPITAL  PARKING  MART  \
# 0               249.0    0      0       0          0         0        0     0
# 1               249.0    1      0       0          0         0        0     0
# 2               545.0    0      0       0          0         0        3     0
# 3               285.0    0      0       0          0         0        0     0
# 4               299.0    0      0       0          0         0        0     0
# ...               ...  ...    ...     ...        ...       ...      ...   ...
# 11749           696.0    0      0       1          0         0        4     0
# 11750           644.0    0      1       0          0         0        1     0
# 11751           644.0    0      1       0          0         0        1     0
# 11752           696.0    0      0       1          0         0        4     0
# 11753           696.0    0      0       1          0         0        4     0
#
#        CONVENIENCE  BANK  OFFICE  PRI_SCHOOL  PUB_SCHOOL
# 0                2     0       0           0           0
# 1                3     0       0           0           0
# 2                1     0       0           0           0
# 3                0     0       0           0           0
# 4                0     0       0           0           0
# ...            ...   ...     ...         ...         ...
# 11749            2     1       0           0           0
# 11750            3     1       1           0           0
# 11751            3     1       1           0           0
# 11752            2     1       0           0           0
# 11753            2     1       0           0           0
#
# [11754 rows x 20 columns]

# %%
#True false
def to_binominal(x):
    return x > 0

binomial_header = ['BUS', 'METRO', 'INFANT', 'PRESCHOOL', 'HOSPITAL', 'PARKING', 'MART', 'CONVENIENCE', 'BANK', 'OFFICE', 'PRI_SCHOOL', 'PUB_SCHOOL']

for head in binomial_header:
    pre_df.loc[:,head] = pre_df[head].copy().apply(to_binominal)

pre_df
# Out:
#        minLease  Type Dir     Old sector divisition  representativeArea  \
# 0       24000.0  OPST  EE     New    가락동        송파구                31.0
# 1       29000.0  OPST  EE     New    가락동        송파구                29.0
# 2       73000.0   APT  EE     Old    가락동        송파구               182.0
# 3       67000.0   APT  EE     New    가락동        송파구               110.0
# 4      125000.0   APT  EE     Old    가락동        송파구               141.0
# ...         ...   ...  ..     ...    ...        ...                 ...
# 11749  130000.0   APT  WS  Common    흥인동         중구               163.0
# 11750   15000.0   APT  SS  Common    흥인동         중구                25.0
# 11751   22200.0  OPST  SS  Common    흥인동         중구                37.0
# 11752  130000.0   APT  SS  Common    흥인동         중구               163.0
# 11753  130000.0   APT  EN  Common    흥인동         중구               163.0
#
#        floorAreaRatio    BUS  METRO  INFANT  PRESCHOOL  HOSPITAL  PARKING  \
# 0               249.0  False  False   False      False     False    False
# 1               249.0   True  False   False      False     False    False
# 2               545.0  False  False   False      False     False     True
# 3               285.0  False  False   False      False     False    False
# 4               299.0  False  False   False      False     False    False
# ...               ...    ...    ...     ...        ...       ...      ...
# 11749           696.0  False  False    True      False     False     True
# 11750           644.0  False   True   False      False     False     True
# 11751           644.0  False   True   False      False     False     True
# 11752           696.0  False  False    True      False     False     True
# 11753           696.0  False  False    True      False     False     True
#
#         MART  CONVENIENCE   BANK  OFFICE  PRI_SCHOOL  PUB_SCHOOL
# 0      False         True  False   False       False       False
# 1      False         True  False   False       False       False
# 2      False         True  False   False       False       False
# 3      False        False  False   False       False       False
# 4      False        False  False   False       False       False
# ...      ...          ...    ...     ...         ...         ...
# 11749  False         True   True   False       False       False
# 11750  False         True   True    True       False       False
# 11751  False         True   True    True       False       False
# 11752  False         True   True   False       False       False
# 11753  False         True   True   False       False       False
#
# [11754 rows x 20 columns]

# %% [markdown]
# ## Scale

# %%
sns.set(rc={'figure.figsize':(30,30)})
# res = sns.heatmap(pre_df.corr().round(2), square=True, cmap='RdYlGn', annot=True, annot_kws={"size": 20})

# res.set_yticklabels(res.get_ymajorticklabels(), fontsize = 15)
# res.set_xticklabels(res.get_xmajorticklabels(), fontsize = 15)

sns.boxplot(x='Dir', y = label, hue='Type', data=pre_df)
# Out:
# <AxesSubplot:xlabel='Dir', ylabel='minLease'>

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

def labelencoder(df):                                     #It convert the catorigcal and string data into numerical values to 
    encoders = {}
    i = 0
    for c in df.columns:      #interperate easily.
        encoders[i] = None
        if df[c].dtype=='object': 
            df[c] = df[c].fillna('N')
            lbl = LabelEncoder()
            lbl.fit(list(df[c].values))
            df[c] = lbl.transform(df[c].values)
            encoders[i] = lbl
        i += 1
    return df, encoders

label_df = pre_df[label]

feature_df, encoders = labelencoder(pre_df[features].copy())

feature_df.isnull().sum()
# Out:
# Type                  0
# Dir                   0
# Old                   0
# sector                0
# divisition            0
# representativeArea    0
# floorAreaRatio        0
# BUS                   0
# METRO                 0
# INFANT                0
# PRESCHOOL             0
# HOSPITAL              0
# PARKING               0
# MART                  0
# CONVENIENCE           0
# BANK                  0
# OFFICE                0
# PRI_SCHOOL            0
# PUB_SCHOOL            0
# dtype: int64

# %% [markdown]
# ## Training

# %%
from  sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(feature_df, label_df, test_size=0.2)

feature_df
# Out:
#        Type  Dir  Old  sector  divisition  representativeArea  floorAreaRatio  \
# 0         1    0    1       0          17                29.0           249.0
# 1         0    0    2       0          17               182.0           545.0
# 2         0    0    1       0          17               110.0           285.0
# 3         0    0    2       0          17               141.0           299.0
# 4         0    0    2       0          17                81.0           343.0
# ...     ...  ...  ...     ...         ...                 ...             ...
# 15487     1    4    0     308          23                43.0           826.0
# 15488     0    1    0     308          23               163.0           696.0
# 15489     0    3    0     308          23                29.0           799.0
# 15490     1    3    0     308          23                37.0           799.0
# 15491     0    5    0     308          23                29.0           799.0
#
#         BUS  METRO  INFANT  PRESCHOOL  HOSPITAL  PARKING   MART  CONVENIENCE  \
# 0      True   True    True       True      True     True   True         True
# 1      True   True    True       True      True     True   True         True
# 2      True   True    True      False      True     True   True         True
# 3      True   True    True       True      True     True   True         True
# 4      True   True    True       True      True     True   True         True
# ...     ...    ...     ...        ...       ...      ...    ...          ...
# 15487  True   True    True       True      True     True   True         True
# 15488  True   True    True       True      True     True   True         True
# 15489  True   True    True       True      True     True  False         True
# 15490  True   True    True       True      True     True  False         True
# 15491  True   True    True       True      True     True  False         True
#
#        BANK  OFFICE  PRI_SCHOOL  PUB_SCHOOL
# 0      True    True       False        True
# 1      True    True       False        True
# 2      True    True       False        True
# 3      True    True       False        True
# 4      True    True       False        True
# ...     ...     ...         ...         ...
# 15487  True    True        True        True
# 15488  True    True        True        True
# 15489  True    True        True        True
# 15490  True    True        True        True
# 15491  True    True        True        True
#
# [15492 rows x 19 columns]

# %%
# creating a object
LR_Model = LinearRegression()
LR_Model.fit(x_train, y_train)
pred = LR_Model.predict(x_test)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 31791.604486727083
# MSE: 2440928014.259853
# RMSE: 49405.74879768399

# %%
def encode(value, encoder, delta = 0):
    for i in range(len(value)):
        if i + delta < 0 : continue
        
        if encoder[i + delta] != None:
            value[i] = encoder[i + delta].transform([value[i]])[0]
    return value

# %%
value = encode(['APT', 'EE', 'Old', '대치동', '강남구', 103, 237, True, False, True, True, False, True, True, True, True, True, True, True], encoders)

LR_Model.predict([value])
# Out:
# array([113059.47951549])

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(pre_df.corr().round(2), square=True, cmap='RdYlGn', annot=True)
# Out:
# <AxesSubplot:>

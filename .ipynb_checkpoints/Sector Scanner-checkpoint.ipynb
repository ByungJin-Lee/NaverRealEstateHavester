# %% [markdown]
# ## Seoul Sector

# %%
#import custom module
import nre.con as nc
import nre.util as nu
import pickle
from tqdm import tqdm_notebook

nu.IS_LOGGING = False

# %%
cur_region = None

regions = nu.get_region_list('0000000000')
if len(regions) == 0: break
for i, region in enumerate(regions): 
    print(i, region)
idx = int(input("원하는 도시 인덱스 : "))
    if idx == -1: break
    cur_region = regions[idx]

regions = nu.get_region_list(cur_region.no)

region_sector = []

for child in seoul_child:
    region_sector.extend(nu.get_region_list(child.no))
    
print('Found', len(region_sector))

for se in region_sector:
    print(se.name)
# Out:
# 0 서울시 1100000000 loc(37.566427 | 126.977872)
# 1 경기도 4100000000 loc(37.274939 | 127.008689)
# 2 인천시 2800000000 loc(37.456054 | 126.705151)
# 3 부산시 2600000000 loc(35.180143 | 129.075413)
# 4 대전시 3000000000 loc(36.350465 | 127.384953)
# 5 대구시 2700000000 loc(35.871390 | 128.601763)
# 6 울산시 3100000000 loc(35.538600 | 129.311375)
# 7 세종시 3600000000 loc(36.592907 | 127.292375)
# 8 광주시 2900000000 loc(35.160032 | 126.851338)
# 9 강원도 4200000000 loc(37.885399 | 127.729750)
# 10 충청북도 4300000000 loc(36.636149 | 127.491238)
# 11 충청남도 4400000000 loc(36.636290 | 126.689570)
# 12 경상북도 4700000000 loc(36.518504 | 128.437796)
# 13 경상남도 4800000000 loc(35.238343 | 128.692400)
# 14 전라북도 4500000000 loc(35.820433 | 127.108875)
# 15 전라남도 4600000000 loc(34.816358 | 126.462443)
# 16 제주도 5000000000 loc(33.488976 | 126.498238)
# 원하는 도시 인덱스(exit -1) : 3
# 0 강서구 2644000000 loc(35.212035 | 128.980525)
# 1 금정구 2641000000 loc(35.243068 | 129.092100)
# 2 기장군 2671000000 loc(35.244507 | 129.222173)
# 3 남구 2629000000 loc(35.136649 | 129.084175)
# 4 동구 2617000000 loc(35.139040 | 129.056900)
# 5 동래구 2626000000 loc(35.205001 | 129.083625)
# 6 부산진구 2623000000 loc(35.162874 | 129.053137)
# 7 북구 2632000000 loc(35.197185 | 128.990438)
# 8 사상구 2653000000 loc(35.152624 | 128.991250)
# 9 사하구 2638000000 loc(35.104476 | 128.974763)
# 10 서구 2614000000 loc(35.097582 | 129.023425)
# 11 수영구 2650000000 loc(35.145640 | 129.113075)
# 12 연제구 2647000000 loc(35.176235 | 129.079762)
# 13 영도구 2620000000 loc(35.091199 | 129.067875)
# 14 중구 2611000000 loc(35.106190 | 129.032338)
# 15 해운대구 2635000000 loc(35.163207 | 129.163700)
# 원하는 도시 인덱스(exit -1) : -1
# Found 250
# 강남구
# 강동구
# 강북구
# 강서구
# 관악구
# 광진구
# 구로구
# 금천구
# 노원구
# 도봉구
# 동대문구
# 동작구
# 마포구
# 서대문구
# 서초구
# 성동구
# 성북구
# 송파구
# 양천구
# 영등포구
# 용산구
# 은평구
# 종로구
# 중구
# 중랑구
# 가평군
# 고양시 덕양구
# 고양시 일산동구
# 고양시 일산서구
# 과천시
# 광명시
# 광주시
# 구리시
# 군포시
# 김포시
# 남양주시
# 동두천시
# 부천시
# 성남시 분당구
# 성남시 수정구
# 성남시 중원구
# 수원시 권선구
# 수원시 영통구
# 수원시 장안구
# 수원시 팔달구
# 시흥시
# 안산시 단원구
# 안산시 상록구
# 안성시
# 안양시 동안구
# 안양시 만안구
# 양주시
# 양평군
# 여주시
# 연천군
# 오산시
# 용인시 기흥구
# 용인시 수지구
# 용인시 처인구
# 의왕시
# 의정부시
# 이천시
# 파주시
# 평택시
# 포천시
# 하남시
# 화성시
# 강화군
# 계양구
# 남동구
# 동구
# 미추홀구
# 부평구
# 서구
# 연수구
# 옹진군
# 중구
# 강서구
# 금정구
# 기장군
# 남구
# 동구
# 동래구
# 부산진구
# 북구
# 사상구
# 사하구
# 서구
# 수영구
# 연제구
# 영도구
# 중구
# 해운대구
# 대덕구
# 동구
# 서구
# 유성구
# 중구
# 남구
# 달서구
# 달성군
# 동구
# 북구
# 서구
# 수성구
# 중구
# 남구
# 동구
# 북구
# 울주군
# 중구
# 세종시
# 광산구
# 남구
# 동구
# 북구
# 서구
# 강릉시
# 고성군
# 동해시
# 삼척시
# 속초시
# 양구군
# 양양군
# 영월군
# 원주시
# 인제군
# 정선군
# 철원군
# 춘천시
# 태백시
# 평창군
# 홍천군
# 화천군
# 횡성군
# 괴산군
# 단양군
# 보은군
# 영동군
# 옥천군
# 음성군
# 제천시
# 증평군
# 진천군
# 청주시 상당구
# 청주시 서원구
# 청주시 청원구
# 청주시 흥덕구
# 충주시
# 계룡시
# 공주시
# 금산군
# 논산시
# 당진시
# 보령시
# 부여군
# 서산시
# 서천군
# 아산시
# 예산군
# 천안시 동남구
# 천안시 서북구
# 청양군
# 태안군
# 홍성군
# 경산시
# 경주시
# 고령군
# 구미시
# 군위군
# 김천시
# 문경시
# 봉화군
# 상주시
# 성주군
# 안동시
# 영덕군
# 영양군
# 영주시
# 영천시
# 예천군
# 울릉군
# 울진군
# 의성군
# 청도군
# 청송군
# 칠곡군
# 포항시 남구
# 포항시 북구
# 거제시
# 거창군
# 고성군
# 김해시
# 남해군
# 밀양시
# 사천시
# 산청군
# 양산시
# 의령군
# 진주시
# 창녕군
# 창원시 마산합포구
# 창원시 마산회원구
# 창원시 성산구
# 창원시 의창구
# 창원시 진해구
# 통영시
# 하동군
# 함안군
# 함양군
# 합천군
# 고창군
# 군산시
# 김제시
# 남원시
# 무주군
# 부안군
# 순창군
# 완주군
# 익산시
# 임실군
# 장수군
# 전주시 덕진구
# 전주시 완산구
# 정읍시
# 진안군
# 강진군
# 고흥군
# 곡성군
# 광양시
# 구례군
# 나주시
# 담양군
# 목포시
# 무안군
# 보성군
# 순천시
# 신안군
# 여수시
# 영광군
# 영암군
# 완도군
# 장성군
# 장흥군
# 진도군
# 함평군
# 해남군
# 화순군
# 서귀포시
# 제주시

# %% [markdown]
# ## Region To Sector

# %%
# region to sector
seq_regions = nu.split_list(region_sector)

print(len(seq_regions))

sectors = []
cancels = []

for regs in seq_regions:
    nu.get_sleep(50)
    se, cn = nu.get_sector_list(regs, loop=tqdm_notebook)
    sectors.extend(se)
    cancels.extend(cn)

with open('%s sectors.data' % cur_region.name, 'wb') as f:
    pickle.dump(sectors, f)
# Out:
# Sector 465

# %%
sectors = None

with open('seoul sectors.data', 'rb') as f:
    sectors = pickle.load(f)

print('Sector', len(sectors))

# %%
import pandas as pd

def old_classifier(x): #old 구분
    value = abs(int(x[0:4]) - 2022)
    if value <= 5:
        return 'New'
    elif value <= 10:
        return 'Common'
    return 'Old'
    
def get_df(sector, things, neighbors, standard):
    nu.update_things_intersection(things, neighbors, nu.get_distance_standard(standard))
    total_df = pd.DataFrame(data=[t.get_list() for t in things], columns=nc.NThing.HEADER)
    total_df['Old'] = total_df['Build'].apply(old_classifier)
    total_df['sector'] = sector.name
    total_df['divisition'] = sector.divisition
    total_df['city'] = sector.city
    total_df.to_csv('./csv/%s - %s house_price.csv' % (sector.name, sector.city), sep=',', na_rep='NaN', index=False)

# %%
error_sector = []
infos = []

for sec in tqdm_notebook(sectors):
    try:
        bundle = nu.get_all_on_sector(sec)
        infos.append(bundle)
    except:
        error_sector.append(sec)
        print('Error', sec)
# Out:
# /var/folders/y8/ldvzwhm13037mvvt3p2d9n0m0000gn/T/ipykernel_11036/2678372075.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for sec in tqdm_notebook(sectors):
#   0%|          | 0/465 [00:00<?, ?it/s]
# Error 서울시 동대문구 신설동 1123010100 loc(37.573942 | 127.024625)
# Error 서울시 성북구 보문동2가 1129013100 loc(37.585828 | 127.018186)
# Error 서울시 성북구 보문동3가 1129013200 loc(37.583874 | 127.015813)
# Error 서울시 성북구 보문동4가 1129012600 loc(37.582882 | 127.021332)
# Error 서울시 성북구 보문동5가 1129012700 loc(37.582588 | 127.020107)
# Error 서울시 성북구 보문동6가 1129012800 loc(37.580475 | 127.018825)
# Error 서울시 성북구 보문동7가 1129012900 loc(37.579733 | 127.022225)
# Error 서울시 성북구 삼선동1가 1129011100 loc(37.584500 | 127.008200)
# Error 서울시 성북구 삼선동2가 1129011200 loc(37.584000 | 127.011400)
# Error 서울시 성북구 안암동3가 1129012300 loc(37.583882 | 127.023100)
# Error 서울시 성북구 안암동4가 1129012400 loc(37.580392 | 127.024663)
# Error 서울시 종로구 궁정동 1111010300 loc(37.584886 | 126.972359)
# Error 서울시 종로구 내자동 1111011400 loc(37.575400 | 126.971600)
# Error 서울시 종로구 누상동 1111010900 loc(37.580400 | 126.962300)
# Error 서울시 종로구 누하동 1111011000 loc(37.579183 | 126.968175)
# Error 서울시 종로구 동숭동 1111016800 loc(37.581300 | 127.005000)
# Error 서울시 종로구 무악동 1111018700 loc(37.576008 | 126.958098)
# Error 서울시 종로구 사간동 1111014400 loc(37.577215 | 126.980529)
# Error 서울시 종로구 사직동 1111011500 loc(37.575363 | 126.965777)
# Error 서울시 종로구 세종로 1111011900 loc(37.579500 | 126.976800)
# Error 서울시 종로구 소격동 1111014200 loc(37.579500 | 126.980775)
# Error 서울시 종로구 송현동 1111014500 loc(37.576800 | 126.981700)
# Error 서울시 종로구 숭인동 1111017500 loc(37.576200 | 127.019300)
# Error 서울시 종로구 신교동 1111010200 loc(37.584500 | 126.967800)
# Error 서울시 종로구 안국동 1111014100 loc(37.577300 | 126.982900)
# Error 서울시 종로구 옥인동 1111011100 loc(37.583600 | 126.962500)
# Error 서울시 종로구 이화동 1111016500 loc(37.577008 | 127.004338)
# Error 서울시 종로구 적선동 1111010700 loc(37.575264 | 126.973889)
# Error 서울시 종로구 중학동 1111012500 loc(37.575174 | 126.979904)
# Error 서울시 종로구 창성동 1111010500 loc(37.580600 | 126.972100)
# Error 서울시 종로구 창신동 1111017400 loc(37.575800 | 127.012063)
# Error 서울시 종로구 체부동 1111011200 loc(37.578000 | 126.970700)
# Error 서울시 종로구 충신동 1111016700 loc(37.574842 | 127.006125)
# Error 서울시 종로구 통의동 1111010600 loc(37.578400 | 126.972638)
# Error 서울시 종로구 통인동 1111010800 loc(37.579797 | 126.970016)
# Error 서울시 종로구 팔판동 1111013900 loc(37.582817 | 126.980400)
# Error 서울시 종로구 사직동 1111011500 loc(37.575363 | 126.965777)
# Error 서울시 종로구 화동 1111014300 loc(37.580600 | 126.982800)
# Error 서울시 종로구 효자동 1111010400 loc(37.582683 | 126.971848)
# Error 서울시 종로구 효제동 1111016200 loc(37.573267 | 127.003013)

# %%
with open('sectors bundles.data', 'wb') as f:
    pickle.dump(infos, f)
    
with open('fail sectors.data', 'wb') as f:
    pickle.dump(error_sector, f)

# %%
s = 100

for info in tqdm_notebook(infos):
    get_df(info[0], info[1], info[2],  {
        'BUS': s,
        'METRO' : s,
        'INFANT' : s,
        'PRESCHOOL' : s,
        'PRI_SCHOOL' : s,
        'PUB_SCHOOL' : s,
        'HOSPITAL' : s,
        'PARKING' : s, 
        'MART' : s,
        'CONVENIENCE': s,
        'WASHING': s,
        'BANK' : s,
        'OFFICE' : s
    })
# Out:
# /var/folders/y8/ldvzwhm13037mvvt3p2d9n0m0000gn/T/ipykernel_11036/3286087952.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for info in tqdm_notebook(infos):
#   0%|          | 0/425 [00:00<?, ?it/s]

# %% [markdown]
# # How to crawling? - Naver Real Estate Map

# %%
#import custom module
import nre.con as nc
import nre.util as nu
from IPython.display import clear_output 
from matplotlib import pyplot as plt
import seaborn as sns

nu.IS_LOGGING = False

# %% [markdown]
# ## 위치을 이용하여 구역 특정

# %%
#loc = nc.NLocation(35.18213, 128.1366) # 진주 충무공동
loc = nc.NLocation(37.49911, 127.065463) # 강남 대치동

#https://new.land.naver.com/complexes?ms=37.49911,127.065463,16&a=APT:OPST&b=B1:A1&e=RETAIL&s=EE

cur_region = nc.NRegion('', loc, '0000000000')

# 검색해서 지역 찾기
# while True:
#     regions = nu.get_region_list(cur_region.no)
#     if len(regions) == 0: break
#     for i, region in enumerate(regions): 
#         print(i, region)
        
#     idx = int(input("원하는 도시 인덱스(exit -1) : "))
#     clear_output()
#     if idx == -1: break
#     cur_region = regions[idx]

# %%
sector = nu.get_sector(cur_region.loc)

print(sector)

#구역 모양
for img in sector.map.get_img():
    plt.imshow(img, cmap='gray')
# Out:
# 서울시 강남구 대치동 1168010600 loc(37.499110 | 127.065463)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/y8/ldvzwhm13037mvvt3p2d9n0m0000gn/T/ipykernel_19468/4096864500.py in <module>
#       5 #구역 모양
#       6 for img in sector.map.get_img():
# ----> 7     plt.imshow(img, cmap='gray')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## 매물 조건 생성

# %%
addon = nc.NAddon(
    #direction=nc.NAddon.DIR_EACH, #전 방향 탐색의 경우 사용 - 아래 로직을 바꾸세요
    tradeType=[nc.NAddon.TRADE_DEAL, nc.NAddon.TRADE_LEASE], #목표 거래 - 매매, 전세
    estateType=[nc.NAddon.ESTATE_APT, nc.NAddon.ESTATE_OPST] #목표 매물 - 아파트, 오피스텔
)

# %% [markdown]
# ## 조건과 구역을 이용하여 매물 탐색

# %%
things = [] # 매물 기록
removed = 0
for dirr in nc.NAddon.DIR_EACH: # 모든 방향 (남향 등등)
    addon.dir = dirr # 방향 조건 선택
    values = []
    for v in nu.get_things(sector, addon):
        if sector.map.is_in(v.loc) is False: # 구역 포함되어있는지
            removed += 1 
            continue 
        v.dir = dirr # 매물 방향 정의
        values.append(v)
    things.extend(values)
print('올바른 매물 수', len(things), '제거됨', removed)
# Out:
# 올바른 매물 수 142 제거됨 17

# %% [markdown]
# ## 구역 주변 편의 시설 탐색

# %%
neighbors = [] # 편의시설 기록
for nType in nc.NNeighbor.EACH: # 모든 편의시설
    values = []
    res = nu.get_neighborhood(sector.loc, nType)
    
    for r in res:
        if sector.map.is_in(r.loc):
            values.append(r)
    neighbors.extend(values)
    print(nType, len(values))
print('Total', len(neighbors))
# Out:
# BUS 47
# METRO 2
# INFANT 29
# PRESCHOOL 3
# SCHOOLPOI 20
# HOSPITAL 0
# PARKING 68
# MART 11
# CONVENIENCE 79
# WASHING 35
# BANK 38
# OFFICE 6
# Total 338

# %% [markdown]
# # 편의시설과 매물 간의 거리 탐색

# %%
# 500 == 걸어서 5~10분 이내, 버스로 1분
# 1000 == 버스로 1~2분 

standard = nu.get_distance_standard() # 거리 기준

for (key, value) in standard.items():
    print(key, value, 'm')
# Out:
# BUS 500
# METRO 500
# INFANT 750
# PRESCHOOL 750
# SCHOOLPOI 2000
# HOSPITAL 5000
# PARKING 500
# MART 500
# CONVENIENCE 250
# WASHING 500
# BANK 1000
# OFFICE 2000

# %%
for thing in things: # 매물
    around = nc.NNeighborAround()
    for nei in neighbors: # 편의시설
        d = nu.distance_between(thing.loc, nei.loc)
        if d <= standard[nei.type]: # meter
            around.increase(nei.type)
    thing.neiAround = around

# %% [markdown]
# ## 시각화

# %%
def old_classifier(x):
    value = abs(int(x[0:4]) - 2022)
    if value <= 5:
        return 'New'
    elif value <= 10:
        return 'Common'
    return 'Old'

# %%
import pandas as pd

thing_df = pd.DataFrame(data=[t.get_list() for t in things], columns=nc.NThing.HEADER)
nei_df = pd.DataFrame(data=[t.neiAround.get_list() for t in things], columns=nc.NNeighborAround.HEADER)

total_df = pd.concat([thing_df, nei_df], axis=1)
total_df['Old'] = total_df['Build'].apply(old_classifier)
total_df['sector'] = sector.name

total_df
# Out:
#                  Name  Type   Build Dir minArea maxArea  representativeArea  \
# 0               세영팔래스   APT  200201  EE   73.77  103.37               103.0
# 1      삼환SOGOOD(주상복합)   APT  200611  EE  107.38  133.52               133.0
# 2    대치대우아이빌명문가(주상복합)   APT  200402  EE   41.88   53.58                41.0
# 3          대치대우아이빌명문가  OPST  200402  EE   57.05   59.01                57.0
# 4                  동양   APT  199901  EE  112.14  112.14               112.0
# ..                ...   ...     ...  ..     ...     ...                 ...
# 137                동양   APT  199901  WN  112.14  112.14               112.0
# 138            대치클래시아  OPST  201512  WN   42.36   61.63                61.0
# 139              바실리체  OPST  202203  WN   67.34  153.29                67.0
# 140                청원   APT  200502  WN  114.52  114.72               114.0
# 141        로프트아파트먼트대치  OPST  201908  WN  109.62  109.62               109.0
#
#      floorAreaRatio   minDeal   maxDeal  ...  SCHOOLPOI  HOSPITAL  PARKING  \
# 0               237  175000.0  200000.0  ...         20         0       20
# 1               359  220000.0  220000.0  ...         20         0       16
# 2               637   31000.0   38000.0  ...         20         0       23
# 3               637   31000.0   32000.0  ...         20         0       23
# 4               223       NaN       NaN  ...         20         0       16
# ..              ...       ...       ...  ...        ...       ...      ...
# 137             223       NaN       NaN  ...         20         0       16
# 138               0   51000.0   65000.0  ...         20         0       10
# 139             799   86000.0  370000.0  ...         20         0       22
# 140             260       NaN       NaN  ...         20         0       19
# 141             249  109000.0  110000.0  ...         20         0       18
#
#      MART  CONVENIENCE  WASHING  BANK  OFFICE     Old  sector
# 0       1           10       14    35       6     Old     대치동
# 1       2            7       10    32       6     Old     대치동
# 2       3           14       10    18       6     Old     대치동
# 3       3           14       10    18       6     Old     대치동
# 4       2            6       12    20       6     Old     대치동
# ..    ...          ...      ...   ...     ...     ...     ...
# 137     2            6       12    20       6     Old     대치동
# 138     4            7        8    26       6  Common     대치동
# 139     2            6        8    19       6     New     대치동
# 140     3           10       12    33       6     Old     대치동
# 141     2            6       10    18       6     New     대치동
#
# [142 rows x 36 columns]

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                142 non-null    object
#  1   Type                142 non-null    object
#  2   Build               142 non-null    object
#  3   Dir                 142 non-null    object
#  4   minArea             142 non-null    object
#  5   maxArea             142 non-null    object
#  6   representativeArea  142 non-null    float64
#  7   floorAreaRatio      142 non-null    int64
#  8   minDeal             127 non-null    float64
#  9   maxDeal             127 non-null    float64
#  10  medianDeal          127 non-null    float64
#  11  minLease            120 non-null    float64
#  12  maxLease            120 non-null    float64
#  13  medianLease         103 non-null    float64
#  14  minDealUnit         127 non-null    float64
#  15  maxDealUnit         127 non-null    float64
#  16  medianDealUnit      127 non-null    float64
#  17  minLeaseUnit        120 non-null    float64
#  18  maxLeaseUnit        120 non-null    float64
#  19  medianLeaseUnit     103 non-null    float64
#  20  Lat                 142 non-null    float64
#  21  Lon                 142 non-null    float64
#  22  BUS                 142 non-null    int64
#  23  METRO               142 non-null    int64
#  24  INFANT              142 non-null    int64
#  25  PRESCHOOL           142 non-null    int64
#  26  SCHOOLPOI           142 non-null    int64
#  27  HOSPITAL            142 non-null    int64
#  28  PARKING             142 non-null    int64
#  29  MART                142 non-null    int64
#  30  CONVENIENCE         142 non-null    int64
#  31  WASHING             142 non-null    int64
#  32  BANK                142 non-null    int64
#  33  OFFICE              142 non-null    int64
#  34  Old                 142 non-null    object
#  35  sector              142 non-null    object
# dtypes: float64(15), int64(13), object(8)
# memory usage: 40.1+ KB

# %%
total_df.describe()
# Out:
#        representativeArea  floorAreaRatio        minDeal        maxDeal  \
# count          142.000000      142.000000     127.000000     127.000000
# mean            99.070423      354.549296  177212.598425  246393.700787
# std             43.509785      251.068344  120745.214498  168972.015974
# min             32.000000        0.000000   26000.000000   29000.000000
# 25%             67.000000      243.000000   71500.000000  107500.000000
# 50%             94.000000      267.500000  185000.000000  220000.000000
# 75%            124.000000      434.000000  252500.000000  370000.000000
# max            225.000000     1096.000000  505000.000000  560000.000000
#
#           medianDeal       minLease       maxLease    medianLease  \
# count     127.000000     120.000000     120.000000     103.000000
# mean   192353.149606  107583.333333  153129.166667  123330.097087
# std    132532.701228   70281.339890  101186.957671   79925.165777
# min     27750.000000   19000.000000   19000.000000   23000.000000
# 25%     78650.000000   65000.000000   70000.000000   67500.000000
# 50%    185000.000000  100000.000000  117500.000000  110000.000000
# 75%    260000.000000  140750.000000  220000.000000  162500.000000
# max    510000.000000  450000.000000  450000.000000  450000.000000
#
#         minDealUnit   maxDealUnit  ...      INFANT   PRESCHOOL  SCHOOLPOI  \
# count    127.000000    127.000000  ...  142.000000  142.000000      142.0
# mean    5623.937008   6533.645669  ...   13.647887    1.633803       20.0
# std     2471.007284   2804.177656  ...    4.755284    0.699330        0.0
# min     1569.000000   1846.000000  ...    8.000000    0.000000       20.0
# 25%     3474.500000   4011.000000  ...   10.000000    1.000000       20.0
# 50%     5797.000000   6494.000000  ...   12.000000    2.000000       20.0
# 75%     7189.000000   8531.000000  ...   16.000000    2.000000       20.0
# max    10093.000000  11702.000000  ...   26.000000    3.000000       20.0
#
#        HOSPITAL     PARKING        MART  CONVENIENCE     WASHING        BANK  \
# count     142.0  142.000000  142.000000   142.000000  142.000000  142.000000
# mean        0.0   18.359155    2.514085     8.105634    9.774648   23.950704
# std         0.0    5.567563    1.397749     4.406165    3.138402    6.551842
# min         0.0    4.000000    0.000000     0.000000    4.000000   14.000000
# 25%         0.0   15.250000    2.000000     6.000000    8.000000   19.000000
# 50%         0.0   19.000000    2.000000     7.000000   10.000000   22.000000
# 75%         0.0   22.000000    3.000000    12.000000   12.000000   30.000000
# max         0.0   34.000000    6.000000    16.000000   19.000000   37.000000
#
#        OFFICE
# count   142.0
# mean      6.0
# std       0.0
# min       6.0
# 25%       6.0
# 50%       6.0
# 75%       6.0
# max       6.0
#
# [8 rows x 28 columns]

# %%
nei_df.describe()
# Out:
#               BUS       METRO      INFANT   PRESCHOOL  SCHOOLPOI  HOSPITAL  \
# count  142.000000  142.000000  142.000000  142.000000      142.0     142.0
# mean     9.676056    0.204225   13.647887    1.633803       20.0       0.0
# std      4.271876    0.454118    4.755284    0.699330        0.0       0.0
# min      4.000000    0.000000    8.000000    0.000000       20.0       0.0
# 25%      6.000000    0.000000   10.000000    1.000000       20.0       0.0
# 50%      8.000000    0.000000   12.000000    2.000000       20.0       0.0
# 75%     14.000000    0.000000   16.000000    2.000000       20.0       0.0
# max     18.000000    2.000000   26.000000    3.000000       20.0       0.0
#
#           PARKING        MART  CONVENIENCE     WASHING        BANK  OFFICE
# count  142.000000  142.000000   142.000000  142.000000  142.000000   142.0
# mean    18.359155    2.514085     8.105634    9.774648   23.950704     6.0
# std      5.567563    1.397749     4.406165    3.138402    6.551842     0.0
# min      4.000000    0.000000     0.000000    4.000000   14.000000     6.0
# 25%     15.250000    2.000000     6.000000    8.000000   19.000000     6.0
# 50%     19.000000    2.000000     7.000000   10.000000   22.000000     6.0
# 75%     22.000000    3.000000    12.000000   12.000000   30.000000     6.0
# max     34.000000    6.000000    16.000000   19.000000   37.000000     6.0

# %% [markdown]
# ## 방향에 따른 가격

# %%
sns.boxplot(x='Dir', y = 'maxDeal', hue='Type', data=total_df)
# Out:
# <AxesSubplot:xlabel='Dir', ylabel='maxDeal'>

# %% [markdown]
# ## 오피스텔과 아파트 차이

# %%
sns.boxplot(x='Type', y = 'maxDeal', data=total_df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='maxDeal'>

# %% [markdown]
# ## 연식에 따른 차이

# %%
sns.boxplot(x='Old', y = 'maxDeal', hue='Type', data=total_df)
# Out:
# <AxesSubplot:xlabel='Old', ylabel='maxDeal'>

# %% [markdown]
# ## 저장

# %%
total_df.to_csv('./csv/%s - %s house_price.csv' % (sector.name, sector.city), sep=',', na_rep='NaN', index=False)

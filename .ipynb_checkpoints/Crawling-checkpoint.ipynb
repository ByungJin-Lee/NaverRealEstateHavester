# %% [markdown]
# # How to crawling?

# %%
#import custom module
import nre.con as nc
import nre.util as nu
import pandas as pd
from IPython.display import clear_output 
import matplotlib.pyplot as plt
import seaborn as sns

nu.IS_LOGGING = False

# %% [markdown]
# ## 위치을 이용하여 구역 특정

# %%
# loc = nc.NLocation(35.18213, 128.1366) # 진주 충무공동
loc = nc.NLocation(37.49911, 127.065463) # 강남 대치동

cur_region = nc.NRegion('', loc, '0000000000')

# 검색해서 지역 찾기
# while True:
#     regions = nu.get_region_list(cur_region.no)
#     if len(regions) == 0: break
#     for i, region in enumerate(regions): 
#         print(i, region)
        
#     idx = int(input("원하는 도시 인덱스(exit -1) : "))
#     clear_output()
#     if idx == -1: break
#     cur_region = regions[idx]
    
sector = nu.get_sector(cur_region.loc)

print(sector)
# Out:
# 서울시 강남구 대치동 1168010600 loc(37.499110 | 127.065463)

# %% [markdown]
# ## 매물 조건 생성

# %%
addon = nc.NAddon(
    tradeType=[nc.NAddon.TRADE_DEAL, nc.NAddon.TRADE_LEASE], #목표 거래 - 매매, 전세
    estateType=[nc.NAddon.ESTATE_APT, nc.NAddon.ESTATE_OPST] #목표 매물 - 아파트, 오피스텔
)

# %% [markdown]
# ## 조건과 구역을 이용하여 매물 탐색

# %%
things = [] # 매물 기록
removed = 0
for dirr in nc.NAddon.DIR_EACH: # 모든 방향 (남향 등등)
    addon.direction = [dirr] # 매물 방향 선택
    res = nu.get_things(sector, addon)
    values = []
    
    for v in res:
        if sector.map.is_in(v.loc) is False: # 구역 포함되어있는지
            removed += 1 
            continue 
        v.dir = dirr # 매물 방향 정의
        values.append(v)
        
    print(dirr, len(values))
    things.extend(values)
    
print('올바른 매물 수', len(things), '제거됨', removed)
# Out:
# EE 22
# ES 19
# WW 10
# WS 19
# SS 47
# EN 8
# NN 10
# WN 6
# 올바른 매물 수 141 제거됨 17

# %% [markdown]
# ## 구역 주변 편의 시설 탐색

# %%
neighbors = [] # 편의시설 기록
for nType in nc.NNeighbor.EACH: # 모든 편의시설
    values = []
    res = nu.get_neighborhood(sector.loc, nType)
    
    for r in res:
        if sector.map.is_in(r.loc):
            values.append(r)
    neighbors.extend(values)
    print(nType, len(values))
print('Total', len(neighbors))
# Out:
# BUS 47
# METRO 2
# INFANT 29
# PRESCHOOL 3
# SCHOOLPOI 20
# HOSPITAL 0
# PARKING 68
# MART 11
# CONVENIENCE 79
# WASHING 35
# BANK 38
# OFFICE 6
# Total 338

# %% [markdown]
# # 편의시설과 매물 간의 거리 탐색

# %%
# 500 == 걸어서 5~10분 이내, 버스로 1분
# 1000 == 버스로 1~2분 

standard = nu.get_distance_standard() # 거리 기준

for (key, value) in standard.items():
    print(key, value)
# Out:
# BUS 500
# METRO 500
# INFANT 750
# PRESCHOOL 750
# SCHOOLPOI 2000
# HOSPITAL 5000
# PARKING 500
# MART 500
# CONVENIENCE 250
# WASHING 500
# BANK 1000
# OFFICE 2000

# %%
for thing in things: # 매물
    around = nc.NNeighborAround()
    for nei in neighbors: # 편의시설
        d = nu.distance_between(thing.loc, nei.loc)
        if d <= standard[nei.type]: # meter
            around.increase(nei.type)
    thing.neiAround = around

# %% [markdown]
# ## 시각화

# %%
thing_list = []
around_nei = []

for t in things: 
    thing_list.append(t.get_list())
    around_nei.append(t.neiAround.get_list())

thing_df = pd.DataFrame(data=thing_list ,columns=nc.NThing.HEADER)
nei_df = pd.DataFrame(data=around_nei, columns=nc.NNeighborAround.HEADER)
total_df = pd.concat([thing_df, nei_df], axis=1)

total_df['sector'] = sector.name

total_df['Type'] = total_df['Type'].map({'아파트' : 'APT', '오피스텔' : 'OPS'})

total_df.head(5)
# Out:
#                Name Type   Build Dir minArea maxArea  representativeArea  \
# 0             세영팔래스  APT  200201  EE   73.77  103.37               103.0
# 1    삼환SOGOOD(주상복합)  APT  200611  EE  107.38  133.52               133.0
# 2  대치대우아이빌명문가(주상복합)  APT  200402  EE   41.88   53.58                41.0
# 3        대치대우아이빌명문가  OPS  200402  EE   57.05   59.01                57.0
# 4                동양  APT  199901  EE  112.14  112.14               112.0
#
#    floorAreaRatio   minDeal   maxDeal  ...  PRESCHOOL  SCHOOLPOI  HOSPITAL  \
# 0             237  175000.0  200000.0  ...          3         20         0
# 1             359  220000.0  220000.0  ...          2         20         0
# 2             637   31000.0   38000.0  ...          1         20         0
# 3             637   31000.0   32000.0  ...          1         20         0
# 4             223       NaN       NaN  ...          2         20         0
#
#    PARKING  MART  CONVENIENCE  WASHING  BANK  OFFICE  sector
# 0       20     1           10       14    35       6     대치동
# 1       16     2            7       10    32       6     대치동
# 2       23     3           14       10    18       6     대치동
# 3       23     3           14       10    18       6     대치동
# 4       16     2            6       12    20       6     대치동
#
# [5 rows x 35 columns]

# %%
nei_df.describe() # 편의시설 접근도
# Out:
#               BUS       METRO      INFANT   PRESCHOOL  SCHOOLPOI  HOSPITAL  \
# count  141.000000  141.000000  141.000000  141.000000      141.0     141.0
# mean     9.709220    0.205674   13.680851    1.638298       20.0       0.0
# std      4.268722    0.455408    4.755927    0.699761        0.0       0.0
# min      4.000000    0.000000    8.000000    0.000000       20.0       0.0
# 25%      6.000000    0.000000   10.000000    1.000000       20.0       0.0
# 50%      8.000000    0.000000   12.000000    2.000000       20.0       0.0
# 75%     14.000000    0.000000   16.000000    2.000000       20.0       0.0
# max     18.000000    2.000000   26.000000    3.000000       20.0       0.0
#
#           PARKING        MART  CONVENIENCE     WASHING        BANK  OFFICE
# count  141.000000  141.000000   141.000000  141.000000  141.000000   141.0
# mean    18.326241    2.510638     8.063830    9.773050   23.992908     6.0
# std      5.573530    1.402126     4.393522    3.149532    6.555801     0.0
# min      4.000000    0.000000     0.000000    4.000000   14.000000     6.0
# 25%     15.000000    2.000000     6.000000    8.000000   19.000000     6.0
# 50%     19.000000    2.000000     7.000000   10.000000   22.000000     6.0
# 75%     22.000000    3.000000    12.000000   12.000000   30.000000     6.0
# max     34.000000    6.000000    16.000000   19.000000   37.000000     6.0

# %%
total_df.describe()
# Out:
#        representativeArea  floorAreaRatio        minDeal        maxDeal  \
# count          141.000000      141.000000     126.000000     126.000000
# mean            99.482270      352.546099  178373.015873  248047.619048
# std             43.386239      250.822005  120514.147493  168611.309568
# min             32.000000        0.000000   26000.000000   29000.000000
# 25%             67.000000      243.000000   86000.000000  110000.000000
# 50%             94.000000      266.000000  185000.000000  220000.000000
# 75%            124.000000      434.000000  253750.000000  370000.000000
# max            225.000000     1096.000000  505000.000000  560000.000000
#
#           medianDeal       minLease       maxLease    medianLease  \
# count     126.000000     119.000000     119.000000     102.000000
# mean   193633.730159  108420.168067  154109.243697  124186.274510
# std    132270.573119   70332.525361  101041.214105   79843.780689
# min     27750.000000   19000.000000   19000.000000   23000.000000
# 25%     86300.000000   65000.000000   70000.000000   70000.000000
# 50%    185000.000000  100000.000000  120000.000000  110000.000000
# 75%    260000.000000  141500.000000  220000.000000  166250.000000
# max    510000.000000  450000.000000  450000.000000  450000.000000
#
#         minDealUnit   maxDealUnit  ...      INFANT   PRESCHOOL  SCHOOLPOI  \
# count    126.000000    126.000000  ...  141.000000  141.000000      141.0
# mean    5649.761905   6564.753968  ...   13.680851    1.638298       20.0
# std     2463.604453   2793.283942  ...    4.755927    0.699761        0.0
# min     1569.000000   1846.000000  ...    8.000000    0.000000       20.0
# 25%     3523.000000   4044.000000  ...   10.000000    1.000000       20.0
# 50%     5797.000000   6588.000000  ...   12.000000    2.000000       20.0
# 75%     7287.000000   8531.000000  ...   16.000000    2.000000       20.0
# max    10093.000000  11702.000000  ...   26.000000    3.000000       20.0
#
#        HOSPITAL     PARKING        MART  CONVENIENCE     WASHING        BANK  \
# count     141.0  141.000000  141.000000   141.000000  141.000000  141.000000
# mean        0.0   18.326241    2.510638     8.063830    9.773050   23.992908
# std         0.0    5.573530    1.402126     4.393522    3.149532    6.555801
# min         0.0    4.000000    0.000000     0.000000    4.000000   14.000000
# 25%         0.0   15.000000    2.000000     6.000000    8.000000   19.000000
# 50%         0.0   19.000000    2.000000     7.000000   10.000000   22.000000
# 75%         0.0   22.000000    3.000000    12.000000   12.000000   30.000000
# max         0.0   34.000000    6.000000    16.000000   19.000000   37.000000
#
#        OFFICE
# count   141.0
# mean      6.0
# std       0.0
# min       6.0
# 25%       6.0
# 50%       6.0
# 75%       6.0
# max       6.0
#
# [8 rows x 28 columns]

# %% [markdown]
# ## Dataframe 저장

# %%
total_df.to_csv('./csv/%s - %s house_price.csv' % (sector.name, sector.city), sep=',', na_rep='NaN', index=False)

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                141 non-null    object
#  1   Type                141 non-null    object
#  2   Build               141 non-null    object
#  3   Dir                 141 non-null    object
#  4   minArea             141 non-null    object
#  5   maxArea             141 non-null    object
#  6   representativeArea  141 non-null    float64
#  7   floorAreaRatio      141 non-null    int64
#  8   minDeal             126 non-null    float64
#  9   maxDeal             126 non-null    float64
#  10  medianDeal          126 non-null    float64
#  11  minLease            119 non-null    float64
#  12  maxLease            119 non-null    float64
#  13  medianLease         102 non-null    float64
#  14  minDealUnit         126 non-null    float64
#  15  maxDealUnit         126 non-null    float64
#  16  medianDealUnit      126 non-null    float64
#  17  minLeaseUnit        119 non-null    float64
#  18  maxLeaseUnit        119 non-null    float64
#  19  medianLeaseUnit     102 non-null    float64
#  20  Lat                 141 non-null    float64
#  21  Lon                 141 non-null    float64
#  22  BUS                 141 non-null    int64
#  23  METRO               141 non-null    int64
#  24  INFANT              141 non-null    int64
#  25  PRESCHOOL           141 non-null    int64
#  26  SCHOOLPOI           141 non-null    int64
#  27  HOSPITAL            141 non-null    int64
#  28  PARKING             141 non-null    int64
#  29  MART                141 non-null    int64
#  30  CONVENIENCE         141 non-null    int64
#  31  WASHING             141 non-null    int64
#  32  BANK                141 non-null    int64
#  33  OFFICE              141 non-null    int64
#  34  sector              141 non-null    object
# dtypes: float64(15), int64(13), object(7)
# memory usage: 38.7+ KB

# %%
boxp = sns.boxplot(x='Dir', y = 'maxDeal', data=total_df) #order=['APT', 'OPS']

# %%
total_df.groupby(by='Dir').describe()
# Out:
#     representativeArea                                                     \
#                  count        mean        std   min    25%    50%     75%
# Dir
# EE                22.0   90.500000  35.198417  41.0  61.00   84.0  123.50
# EN                 8.0   70.875000  27.523691  32.0  58.25   64.0   79.00
# ES                19.0  106.842105  39.620790  44.0  79.00  104.0  129.50
# NN                10.0   79.700000  36.566682  32.0  50.00   73.0  109.00
# SS                47.0  116.723404  50.819674  32.0  74.50  110.0  149.00
# WN                 6.0   84.000000  31.546791  41.0  62.50   88.0  111.25
# WS                19.0   96.473684  38.877826  56.0  68.00   88.0  112.00
# WW                10.0   81.900000  31.620844  44.0  68.25   77.5   86.00
#
#            floorAreaRatio              ...   BANK       OFFICE                 \
#        max          count        mean  ...    75%   max  count mean  std  min
# Dir                                    ...
# EE   157.0           22.0  423.000000  ...  28.00  36.0   22.0  6.0  0.0  6.0
# EN   114.0            8.0  365.750000  ...  22.25  33.0    8.0  6.0  0.0  6.0
# ES   202.0           19.0  302.210526  ...  30.00  36.0   19.0  6.0  0.0  6.0
# NN   142.0           10.0  510.800000  ...  20.75  31.0   10.0  6.0  0.0  6.0
# SS   225.0           47.0  299.702128  ...  31.00  37.0   47.0  6.0  0.0  6.0
# WN   114.0            6.0  361.333333  ...  24.50  33.0    6.0  6.0  0.0  6.0
# WS   202.0           19.0  290.000000  ...  30.50  36.0   19.0  6.0  0.0  6.0
# WW   152.0           10.0  486.300000  ...  30.00  36.0   10.0  6.0  0.0  6.0
#
#
#      25%  50%  75%  max
# Dir
# EE   6.0  6.0  6.0  6.0
# EN   6.0  6.0  6.0  6.0
# ES   6.0  6.0  6.0  6.0
# NN   6.0  6.0  6.0  6.0
# SS   6.0  6.0  6.0  6.0
# WN   6.0  6.0  6.0  6.0
# WS   6.0  6.0  6.0  6.0
# WW   6.0  6.0  6.0  6.0
#
# [8 rows x 224 columns]

# %% [markdown]
# # How to crawling?

# %%
#import custom module
import nre.con as nc
import nre.util as nu
import pandas as pd
from IPython.display import clear_output 
import matplotlib.pyplot as plt
import seaborn as sns

nu.IS_LOGGING = False

# %% [markdown]
# ## 위치을 이용하여 구역 특정

# %%
# loc = nc.NLocation(35.18213, 128.1366) # 진주 충무공동
loc = nc.NLocation(37.49911, 127.065463) # 강남 대치동

cur_region = nc.NRegion('', loc, '0000000000')

# 검색해서 지역 찾기
while True:
    regions = nu.get_region_list(cur_region.no)
    if len(regions) == 0: break
    for i, region in enumerate(regions): 
        print(i, region)
        
    idx = int(input("원하는 도시 인덱스(exit -1) : "))
    clear_output()
    if idx == -1: break
    cur_region = regions[idx]
    
sector = nu.get_sector(cur_region.loc)

print(sector)
# Out:
# 서울시 강남구 삼성동 1168010500 loc(37.514792 | 127.055387)

# %% [markdown]
# ## 매물 조건 생성

# %%
addon = nc.NAddon(
    tradeType=[nc.NAddon.TRADE_DEAL, nc.NAddon.TRADE_LEASE], #목표 거래 - 매매, 전세
    estateType=[nc.NAddon.ESTATE_APT, nc.NAddon.ESTATE_OPST] #목표 매물 - 아파트, 오피스텔
)

for poly in sector.map.polys:
    poly
# Out:
# GEOMETRYCOLLECTION EMPTY
# POLYGON ((37.525066 127.06547, 37.52496 127.06647, 37.524612 127.06746, 37.524582 127.067505, 37.519863 127.06769, 37.510303 127.068886, 37.509895 127.06652, 37.50452 127.04901, 37.505863 127.04836, 37.506424 127.047935, 37.508213 127.04517, 37.50904 127.04439, 37.517212 127.041275, 37.520054 127.05707, 37.521904 127.06239, 37.521835 127.06272, 37.52196 127.06285, 37.52166 127.06317, 37.521618 127.063736, 37.525066 127.06547))

# %% [markdown]
# ## 조건과 구역을 이용하여 매물 탐색

# %%
things = [] # 매물 기록
removed = 0
for dirr in nc.NAddon.DIR_EACH: # 모든 방향 (남향 등등)
    addon.direction = [dirr] # 매물 방향 선택
    res = nu.get_things(sector, addon)
    
    for v in res:
        if sector.map.is_in(v.loc) is False: # 구역 포함되어있는지
            removed += 1 
            continue 
        v.dir = dirr # 매물 방향 정의
        things.append(v)
    
print('올바른 매물 수', len(things), '제거됨', removed)
# Out:
# 올바른 매물 수 672 제거됨 216

# %% [markdown]
# ## 구역 주변 편의 시설 탐색

# %%
neighbors = [] # 편의시설 기록
for nType in nc.NNeighbor.EACH: # 모든 편의시설
    values = []
    res = nu.get_neighborhood(sector.loc, nType)
    
    for r in res:
        if sector.map.is_in(r.loc):
            values.append(r)
    neighbors.extend(values)
    print(nType, len(values))
print('Total', len(neighbors))
# Out:
# BUS 44
# METRO 3
# INFANT 20
# PRESCHOOL 1
# SCHOOLPOI 22
# HOSPITAL 12
# PARKING 84
# MART 2
# CONVENIENCE 83
# WASHING 31
# BANK 50
# OFFICE 12
# Total 364

# %% [markdown]
# # 편의시설과 매물 간의 거리 탐색

# %%
# 500 == 걸어서 5~10분 이내, 버스로 1분
# 1000 == 버스로 1~2분 

standard = nu.get_distance_standard() # 거리 기준

for (key, value) in standard.items():
    print(key, value)
# Out:
# BUS 500
# METRO 500
# INFANT 750
# PRESCHOOL 750
# SCHOOLPOI 2000
# HOSPITAL 5000
# PARKING 500
# MART 500
# CONVENIENCE 250
# WASHING 500
# BANK 1000
# OFFICE 2000

# %%
for thing in things: # 매물
    around = nc.NNeighborAround()
    for nei in neighbors: # 편의시설
        d = nu.distance_between(thing.loc, nei.loc)
        if d <= standard[nei.type]: # meter
            around.increase(nei.type)
    thing.neiAround = around

# %% [markdown]
# ## 시각화

# %%
thing_list = []
around_nei = []

for t in things: 
    thing_list.append(t.get_list())
    around_nei.append(t.neiAround.get_list())

thing_df = pd.DataFrame(data=thing_list ,columns=nc.NThing.HEADER)
nei_df = pd.DataFrame(data=around_nei, columns=nc.NNeighborAround.HEADER)
total_df = pd.concat([thing_df, nei_df], axis=1)

total_df['sector'] = sector.name

total_df['Type'] = total_df['Type'].map({'아파트' : 'APT', '오피스텔' : 'OPS'})

total_df.head(5)
# Out:
#              Name Type   Build Dir minArea maxArea  representativeArea  \
# 0    삼성팰리스(71-16)  APT  200610  EE   130.7   130.7               130.0
# 1  브라운스톤레전드(주상복합)  APT  200908  EE  257.94  257.94               257.0
# 2   삼성포스코더샵(주상복합)  APT  200308  EE  176.57  183.77               183.0
# 3    삼성대우멤버스카운티5차  APT  200511  EE  136.06  136.06               136.0
# 4           삼성웰피아  APT  200506  EE  120.23  120.23               120.0
#
#    floorAreaRatio  minDeal  maxDeal  ... PRESCHOOL  SCHOOLPOI  HOSPITAL  \
# 0             249        0        0  ...         1         22        12
# 1             599   450000   480000  ...         0         20        12
# 2             849   300000   340000  ...         1         22        12
# 3             199   220000   220000  ...         0         22        12
# 4             196        0        0  ...         0         22        12
#
#   PARKING  MART  CONVENIENCE WASHING  BANK  OFFICE sector
# 0      19     2            4      13    41      12    삼성동
# 1       2     0            4       7    10      11    삼성동
# 2      29     2           10      10    46      12    삼성동
# 3       6     0            5      10    11      11    삼성동
# 4      21     1            4       7    37      12    삼성동
#
# [5 rows x 35 columns]

# %%
nei_df.describe() # 편의시설 접근도
# Out:
#               BUS       METRO      INFANT   PRESCHOOL   SCHOOLPOI  HOSPITAL  \
# count  672.000000  672.000000  672.000000  672.000000  672.000000     672.0
# mean     7.130952    0.535714    8.857143    0.476190   21.869048      12.0
# std      2.660210    0.544780    3.319608    0.499805    0.457552       0.0
# min      2.000000    0.000000    4.000000    0.000000   20.000000      12.0
# 25%      5.000000    0.000000    6.000000    0.000000   22.000000      12.0
# 50%      7.000000    1.000000    8.000000    0.000000   22.000000      12.0
# 75%      9.000000    1.000000   11.250000    1.000000   22.000000      12.0
# max     14.000000    2.000000   16.000000    1.000000   22.000000      12.0
#
#          PARKING        MART  CONVENIENCE     WASHING        BANK      OFFICE
# count  672.00000  672.000000   672.000000  672.000000  672.000000  672.000000
# mean    15.75000    0.654762     4.821429    7.988095   30.642857   11.738095
# std      9.88865    0.794828     2.570778    4.216196   11.683499    0.537567
# min      1.00000    0.000000     1.000000    2.000000   10.000000   10.000000
# 25%      8.00000    0.000000     3.000000    5.000000   22.750000   12.000000
# 50%     15.50000    0.000000     4.000000    7.000000   33.000000   12.000000
# 75%     23.00000    1.000000     6.000000   10.000000   40.000000   12.000000
# max     35.00000    2.000000    13.000000   19.000000   46.000000   12.000000

# %%
total_df.describe()
# Out:
#        representativeArea  floorAreaRatio        minDeal       maxDeal  \
# count          672.000000      672.000000     672.000000  6.720000e+02
# mean           120.345238      348.821429  177816.666667  2.215931e+05
# std             53.608615      211.206747  150036.432999  2.278043e+05
# min             28.000000        0.000000       0.000000  0.000000e+00
# 25%             81.750000      245.750000   39625.000000  6.675000e+04
# 50%            111.000000      274.000000  175000.000000  2.000000e+05
# 75%            149.500000      373.500000  260000.000000  3.000000e+05
# max            287.000000      943.000000  700000.000000  1.660000e+06
#
#             minLease       maxLease   minDealUnit   maxDealUnit  minLeaseUnit  \
# count     672.000000     672.000000    672.000000    672.000000    672.000000
# mean    79589.880952   96467.857143   4815.119048   5413.190476   2436.011905
# std     69342.901295   81234.386148   3043.612981   3579.833013   1664.369324
# min         0.000000       0.000000      0.000000      0.000000      0.000000
# 25%         0.000000       0.000000   3051.750000   3424.500000      0.000000
# 50%     80000.000000   90000.000000   5395.500000   5774.500000   2940.500000
# 75%    116250.000000  160000.000000   6957.250000   7323.000000   3544.000000
# max    350000.000000  350000.000000  10301.000000  15906.000000   7323.000000
#
#        maxLeaseUnit  ...      INFANT   PRESCHOOL   SCHOOLPOI  HOSPITAL  \
# count    672.000000  ...  672.000000  672.000000  672.000000     672.0
# mean    2702.738095  ...    8.857143    0.476190   21.869048      12.0
# std     1997.143475  ...    3.319608    0.499805    0.457552       0.0
# min        0.000000  ...    4.000000    0.000000   20.000000      12.0
# 25%        0.000000  ...    6.000000    0.000000   22.000000      12.0
# 50%     3217.500000  ...    8.000000    0.000000   22.000000      12.0
# 75%     3852.500000  ...   11.250000    1.000000   22.000000      12.0
# max    10626.000000  ...   16.000000    1.000000   22.000000      12.0
#
#          PARKING        MART  CONVENIENCE     WASHING        BANK      OFFICE
# count  672.00000  672.000000   672.000000  672.000000  672.000000  672.000000
# mean    15.75000    0.654762     4.821429    7.988095   30.642857   11.738095
# std      9.88865    0.794828     2.570778    4.216196   11.683499    0.537567
# min      1.00000    0.000000     1.000000    2.000000   10.000000   10.000000
# 25%      8.00000    0.000000     3.000000    5.000000   22.750000   12.000000
# 50%     15.50000    0.000000     4.000000    7.000000   33.000000   12.000000
# 75%     23.00000    1.000000     6.000000   10.000000   40.000000   12.000000
# max     35.00000    2.000000    13.000000   19.000000   46.000000   12.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ## Dataframe 저장

# %%
total_df.to_csv('./csv/house_price_data %s.csv' % sector.name, sep=',', na_rep='NaN', index=False)

# %%
total_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                672 non-null    object
#  1   Type                672 non-null    object
#  2   Build               672 non-null    object
#  3   Dir                 672 non-null    object
#  4   minArea             672 non-null    object
#  5   maxArea             672 non-null    object
#  6   representativeArea  672 non-null    float64
#  7   floorAreaRatio      672 non-null    int64
#  8   minDeal             672 non-null    int64
#  9   maxDeal             672 non-null    int64
#  10  medianDeal          672 non-null    object
#  11  minLease            672 non-null    int64
#  12  maxLease            672 non-null    int64
#  13  medianLease         672 non-null    object
#  14  minDealUnit         672 non-null    int64
#  15  maxDealUnit         672 non-null    int64
#  16  medianDealUnit      672 non-null    object
#  17  minLeaseUnit        672 non-null    int64
#  18  maxLeaseUnit        672 non-null    int64
#  19  medianLeaseUnit     672 non-null    object
#  20  Lat                 672 non-null    float64
#  21  Lon                 672 non-null    float64
#  22  BUS                 672 non-null    int64
#  23  METRO               672 non-null    int64
#  24  INFANT              672 non-null    int64
#  25  PRESCHOOL           672 non-null    int64
#  26  SCHOOLPOI           672 non-null    int64
#  27  HOSPITAL            672 non-null    int64
#  28  PARKING             672 non-null    int64
#  29  MART                672 non-null    int64
#  30  CONVENIENCE         672 non-null    int64
#  31  WASHING             672 non-null    int64
#  32  BANK                672 non-null    int64
#  33  OFFICE              672 non-null    int64
#  34  sector              672 non-null    object
# dtypes: float64(3), int64(21), object(11)
# memory usage: 183.9+ KB

# %%
sns.barplot(x='Type', y = 'minDeal', data=total_df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='minDeal'>
